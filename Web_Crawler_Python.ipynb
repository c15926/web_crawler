# %% [markdown]
# <a href="https://colab.research.google.com/github/c15926/web_crawler/blob/master/Web_Crawler_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# 한 건의 대화에 대한 정보를 담는 클래스이빈다.

class Conversation:
  # 질문(question), 응답(answer) 두 변수로 구성됩니다.
  def __init__(self, question, answer):
    self.question = question
    self.answer = answer

  def __str__(self):
    return "질문 :" + self.question + "\n 답변 : " + self.answer + "\n"

# 모든 영어 대화 주제를 추출하는 함수입니다.
def get_subjects():
  subjects = []

  #  전체 주제 목록을 보여주는 페이지로의 요청 객체를 생성합니다.

  req = requests.get('https://basicenglishspeaking.com/daily-english-conversation-topics/')
  html = req.text
  soup = BeautifulSoup(html, 'html.parser')

  divs = soup.findAll('div', {"class": "tcb-flex-row tcb--cols--3"})

  for div in divs:
    #내부 존재하는 <a> 태그들을 추출합니다.
    links = div.findAll('a')

    #<a> 태그 내부의 텍스트를 테스트에 삽입합니다.

    for link in links:
      subject = link.text
      subjects.append(subject)

    return subjects

subjects = get_subjects()
print('총 ', len(subjects), '개의 주제를 찾았습니다.')
print(subjects)
# Out:
# 총  75 개의 주제를 찾았습니다.
# ...

# %%
coversations = []
i = 1

# 모든 대화 주제 각각에 접근합니다.

for sub in subjects:
  print('(', i,'/', len(subjects), ')', sub)

  # 대화 스크립트를 보여주는 페이저로의 요청 객체를 생성합니다.
  req = requests.get('https://basicenglishspeaking.com/' + sub)
  html = req.text
  soup = BeautifulSoup(html, 'html.parser')

  qnas = soup.findAll('div', {"class": "sc_player_container1"})

  ## 각각의 대화 내용에 모두 접근합니다.

  for qna in qnas:
    if qnas.index(qna) % 2 == 0:
      q = qna.next_sibling
    else:
      a = qna.next_sibling
      c = Conversation(q,a)
      coversations.append(c)

  i = i+1

  if i == 10:
      break;

print("총", len(coversations), "개의 대화를 찾았습니다.")

for c in coversations:
  print(str(c))
# Out:
# ( 1 / 75 ) Family
# ( 2 / 75 ) Restaurant
# ( 3 / 75 ) Books
# ( 4 / 75 ) Travel
# ( 5 / 75 ) Website
# ( 6 / 75 ) Accident
# ( 7 / 75 ) Childhood memory
# ( 8 / 75 ) Favorite rooms
# ( 9 / 75 ) Presents
# 총 64 개의 대화를 찾았습니다.
# 질문 :How many people are there in your family?
#  답변 : There are 5 people in my family: my father, mother, brother, sister, and me.
#
# 질문 :Does your family live in a house or an apartment?
#  답변 : We live in a house in the countryside.
#
# 질문 :What does your father do?
#  답변 : My father is a doctor. He works at the local hospital.
#
# 질문 :How old is your mother?
#  답변 : She is 40 years old, 1 year younger than my father.
#
# 질문 :Do you have any siblings? What’s his/her name?
#  답변 : Yes, I do. I have 1 elder brother, David, and 1 younger sister, Mary.
#
# 질문 :Are you the oldest amongst your brothers and sisters?
#  답변 : No, I’m not. I’m the second child in my family.
#
# 질문 :What do your mother/father like?
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 한 건의 대화에 대한 정보를 담는 클래스이빈다.

# 모든 영어 대화 주제를 추출하는 함수입니다.
def get_subjects():
  subjects = []

  #  전체 주제 목록을 보여주는 페이지로의 요청 객체를 생성합니다.

  req = requests.get('https://www.naver.com')
  html = req.text
  soup = BeautifulSoup(html, 'html.parser')

  divs = soup.findAll('div', {"class": "gnb_inner"})


  for div in divs:
    #내부 존재하는 <a> 태그들을 추출합니다.
    links = div.findAll('a')

    #<a> 태그 내부의 텍스트를 테스트에 삽입합니다.

    for link in links:
      subject = link.text
      subjects.append(subject)

    return subjects

subjects = get_subjects()
print('총 ', len(subjects), '개의 주제를 찾았습니다.')
print(subjects)
# Out:
# 총  21 개의 주제를 찾았습니다.
# ['메일', '카페', '블로그', '지식iN', '쇼핑', 'Pay', 'TV', '사전', '뉴스', '증권', '부동산', '지도', '영화', '뮤직', '책', '웹툰', '더보기', '서비스 전체보기', '메뉴설정', '초기화', '저장']

# %%
import requests
from bs4 import BeautifulSoup

# 한 건의 대화에 대한 정보를 담는 클래스이빈다.

# 모든 영어 대화 주제를 추출하는 함수입니다.
def get_subjects():
  subjects = []

  #  전체 주제 목록을 보여주는 페이지로의 요청 객체를 생성합니다.

  req = requests.get('https://www.kma.ac.kr')
  html = req.text
  soup = BeautifulSoup(html, 'html.parser')

  divs = soup.findAll('div', {"class": "recentBbsInfo"})


  for div in divs:
    #내부 존재하는 <a> 태그들을 추출합니다.
    links = div.findAll('a')

    #<a> 태그 내부의 텍스트를 테스트에 삽입합니다.

    for link in links:
      subject = link.text
      subjects.append(subject)

    return subjects

subjects = get_subjects()
print('총 ', len(subjects), '개의 주제를 찾았습니다.')
print(subjects)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# ...
